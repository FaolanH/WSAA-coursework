# %% [markdown]
# ### Author: Faolán Hamilton
#
# Write a program in python that will read a file from a repository, replacing all the instances of the text "Andrew" with my name "Faolán".
#
# The program should then commit these changes and push the file back to the repository, requiring authorisation to do this.
#
# Marks will be given for the functionality and layout of the code; with minimal comments to indicate I know what the program is doing.

# %% [markdown]
# ##### I will be using the book.json file which uses a book by Andrew Beatty.

# %%
import json

# %%
# Source: https://stackoverflow.com/questions/53077503/how-to-find-and-replace-a-part-of-a-value-in-json-file
# opening the json file, calling it booklist
with open('book.json') as booklist:
    data = json.load(booklist)

for item in data['Books']:
    # it would not accept the fada in my name
    item['Author'] = item['Author'].replace('Andrew Beatty', 'Faolan Hamilton')
# w allows for the addition above to be written into a new file
with open('new_book.json', 'w') as booklist:
    json.dump(data, booklist)
