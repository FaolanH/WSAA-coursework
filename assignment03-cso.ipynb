# %% [markdown]
# ### Author: Faolán Hamilton
#
# Write a short program <10 lines that retrieves the dataset (no reformating or analyses neccessary) for the "exchequer account (historical series)" from the CSO, and stores it into a file called "cso.json".
#
# I will need to find the dataset in CSO.ie, try economic and then finance, then finance indicators. yes it is difficult to find, that is part of the task, actually the easiest way to find it is search for it.
