# %% [markdown]
# ### Author: Faolán Hamilton

# %% [markdown]
# ## Defining the assignment:
#
# Using Deck of Cards API (https://deckofcardsapi.com/) an API that simulates dealing a deck of cards, write a program that "deals" (prints out) 5 cards.
#
# Step 1: Shuffle (https://deckofcardsapi.com/api/deck/new/shuffle/?deck_count=1)
#
# Step 2: Get the deck_id
#
# Step 3: With the deck_id you can get the cards (https://deckofcardsapi.com/api/deck/<<deck_id>>/draw/?count=2)
#
# The above example gets two cards (dependent on count)
#
# Step 4: Print the value and the suit of each card
#
# Step 5: Save the file as assignment2-carddraw.ipynb
#
# Additional (optional) step: Check if the user has drawn a pair, triple, straight, or all of the same suit and congratulate the user.

# %%
import requests
import csv
from xml.dom.minidom import parseString

# %%
url = "https://deckofcardsapi.com"

page = requests.get(url)
doc = parseString(page.content)

print(doc.toprettyxml())
# Out:
# ---------------------------------------------------------------------------
# ExpatError                                Traceback (most recent call last)
# Cell In[26], line 4
#       1 url = "https://deckofcardsapi.com"
#       3 page = requests.get(url)
# ----> 4 doc = parseString(page.content)
#       6 print(doc.toprettyxml())
#
# File /usr/local/python/3.12.1/lib/python3.12/xml/dom/minidom.py:2000, in parseString(string, parser)
#    1998 if parser is None:
#    1999     from xml.dom import expatbuilder
# -> 2000     return expatbuilder.parseString(string)
#    2001 else:
#    2002     from xml.dom import pulldom
#
# File /usr/local/python/3.12.1/lib/python3.12/xml/dom/expatbuilder.py:922, in parseString(string, namespaces)
#     920 else:
#     921     builder = ExpatBuilder()
# --> 922 return builder.parseString(string)
#
# File /usr/local/python/3.12.1/lib/python3.12/xml/dom/expatbuilder.py:220, in ExpatBuilder.parseString(self, string)
#     218 parser = self.getParser()
#     219 try:
# --> 220     parser.Parse(string, True)
#     221     self._setup_subset(string)
#     222 except ParseEscape:
#
# ExpatError: mismatched tag: line 254, column 4
